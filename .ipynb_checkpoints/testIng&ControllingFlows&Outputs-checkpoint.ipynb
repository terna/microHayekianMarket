# %%
import numpy as np

# %%
def f():
    global a, b
    a=100
    b=200
    np.random.seed(111)

# %%
f()

# %%
a, b, np.random.uniform(0,1)
# Out:
# (100, 200, 0.6121701756176187)

# %%
from ipywidgets import Output
from IPython.display import clear_output
from IPython.display import display

out = Output()
display(out)

with out:
    print(1)
print(2)
# Out:
# Output()
# 2

# %%
with out:
    clear_output()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from ipywidgets import Output
from IPython.display import clear_output
from IPython.display import display

# %%
out = Output()
display(out)
fig1=plt.figure(1)
plt.plot([1,-1,2])
plt.show(fig1)
for _ in range(2):
    fig2=plt.figure(2,clear=True)
    plt.plot([1,2,3]);
    display(plt.show(fig2,block=False))
    plt.pause(1) 
    plt.close(fig2)
fig3=plt.figure(3)
plt.plot([-1,1,-1,1])

# %%
plt.close()
